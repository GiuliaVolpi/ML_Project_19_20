# %%
import sys
from os import path
sys.path.insert(0, "../../ISANet/")
sys.path.insert(0, "./")

from isanet.model import Mlp
from isanet.optimizer import SGD
from isanet.datasets.monk import load_monk
from isanet.utils.model_utils import printMSE, printAcc, plotHistory
import numpy as np
from tabulate import tabulate

# %%
def print_table(data):
    table = [["Training Set",data[0],data[1]],
         ["Test Set",data[2],data[3]]]
    print(tabulate(table, headers=["MSE", "Accuracy"]))

def print_table_final(data):
    table = [["Training Set",data[0],data[1], data[2], data[3]],
         ["Test Set",data[4],data[5],data[6], data[7] ]]
    print(tabulate(table, headers=["Mean mse","Std mse", "Mean Accuracy", "Std Accuracy"]))

# %% [markdown]
# # - monk 1

# %%
print("Load Monk DataSet")
X_train, Y_train = load_monk("1", "train")
X_test, Y_test = load_monk("1", "test")
# Out:
# Load Monk DataSet

# %%
len(X_train)

# %% [markdown]
# ## test:
# - 17->3->1
# - lr: 0.2
# - kernel_regularizer: 0
# - momentum: 0.2
# - nesterov: True

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 0.003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.2,
        momentum = 0.2,
        nesterov = True
    ))

model.fit(X_train,
            Y_train, 
            epochs=600, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                    MSE    Accuracy
# ------------  --------  ----------
# Training Set  0.249994         0.5
# Test Set      0.249996         0.5

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 0.003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.2,
        momentum = 0.2,
        nesterov = True
    ))

model.fit(X_train,
            Y_train, 
            epochs=3000, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                    MSE    Accuracy
# ------------  --------  ----------
# Training Set  0.145499    0.846774
# Test Set      0.188262    0.736111

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 0.003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.9,
        momentum = 0.2,
        nesterov = True
    ))

model.fit(X_train,
            Y_train, 
            epochs=3000, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                    MSE    Accuracy
# ------------  --------  ----------
# Training Set  0.077371    0.935484
# Test Set      0.106762    0.914352

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 0.0003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.0003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.8,
        momentum = 0.9,
        nesterov = True
    ))

model.fit(X_train,
            Y_train, 
            epochs=800, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                     MSE    Accuracy
# ------------  ---------  ----------
# Training Set  0.0032912    1
# Test Set      0.0213246    0.972222

# %%
model = Mlp()
model.add(4, input= 17, kernel_initializer = 0.0003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.0003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.8,
        momentum = 0.9,
        nesterov = True
    ))

model.fit(X_train,
            Y_train, 
            epochs=800, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                     MSE    Accuracy
# ------------  ---------  ----------
# Training Set  0.0651969    0.935484
# Test Set      0.0845562    0.916667

# %%
model = Mlp()
model.add(4, input= 17, kernel_initializer = 0.0003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.0003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.1,
        momentum = 0.3,
        nesterov = True
    ))

model.fit(X_train,
            Y_train, 
            epochs=300, 
            batch_size=1,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                     MSE    Accuracy
# ------------  ---------  ----------
# Training Set  0.0362932    0.959677
# Test Set      0.0682808    0.916667

# %%
model = Mlp()
model.add(4, input= 17, kernel_initializer = 0.0003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.0003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.8,
        momentum = 0.9,
        nesterov = True
    ))

model.fit(X_train,
            Y_train, 
            epochs=150, 
            batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                      MSE    Accuracy
# ------------  ----------  ----------
# Training Set  0.00276349           1
# Test Set      0.00438264           1

# %%
model = Mlp()
model.add(7, input= 17, kernel_initializer = 0.0003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.0003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.8,
        momentum = 0.9,
        nesterov = True
    ))

model.fit(X_train,
            Y_train, 
            epochs=1000, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                     MSE    Accuracy
# ------------  ---------  ----------
# Training Set  0.0649432    0.935484
# Test Set      0.0840891    0.916667

# %% [markdown]
# # final model monk 1

# %%
np.random.seed(50)
mse_means_train = []
accs_means_train = []

mse_means_val = []
accs_means_val = []
for i in range(0,9):
    print("It. {}".format(i))
    model = Mlp()
    model.add(4, input= 17, kernel_initializer = 0.0001, kernel_regularizer = 0)
    model.add(1, kernel_initializer = 0.0001, kernel_regularizer = 0)

    model.set_optimizer(
        SGD(
            lr = 0.81,
            momentum = 0.9,
            nesterov = True
        ))
    model.fit(X_train,
                Y_train, 
                epochs=1200, 
                #batch_size=31,
                validation_data = [X_test, Y_test],
                verbose=0) 
    #outputNet = model.predict(X_test)
    
    mse_means_train.append(model.history["loss_mse"][-1])
    accs_means_train.append(model.history["acc"][-1])
    mse_means_val.append(model.history["val_loss_mse"][-1])
    accs_means_val.append(model.history["val_acc"][-1])
    
    #printMSE(outputNet, Y_test, type = "test")
    #printAcc(outputNet, Y_test, type = "test")
    print("Training: MSE = {}, Accuracy = {}".format(model.history["loss_mse"][-1],model.history["acc"][-1]))
    print("Test: MSE = {}, Accuracy = {}".format(model.history["val_loss_mse"][-1],model.history["val_acc"][-1]))
    plotHistory(model.history )
print("Final result")
plotHistory(model.history )
data = [    np.mean(mse_means_train),
            np.std(mse_means_train),
            np.mean(accs_means_train),
            np.std(accs_means_train),
            np.mean(mse_means_val),
            np.std(mse_means_val),
            np.mean(accs_means_val),
            np.std(accs_means_val)
       ]
print_table_final(data)
# Out:
# It. 0
# Training: MSE = 0.0031865875723768662, Accuracy = 1.0
# Test: MSE = 0.006048954438652704, Accuracy = 1.0
# It. 1
# Training: MSE = 0.0032900152639632504, Accuracy = 1.0
# Test: MSE = 0.005470372345871061, Accuracy = 1.0
# It. 2
# Training: MSE = 0.0023103792553142255, Accuracy = 1.0
# Test: MSE = 0.0040337998704018645, Accuracy = 1.0
# It. 3
# Training: MSE = 0.0024392351462460228, Accuracy = 1.0
# Test: MSE = 0.0043620660299409615, Accuracy = 1.0
# It. 4
# Training: MSE = 0.0017699952416977288, Accuracy = 1.0
# Test: MSE = 0.0027995343590091213, Accuracy = 1.0
# It. 5
# Training: MSE = 0.06542747580148316, Accuracy = 0.9354838709677419
# Test: MSE = 0.0848951956012493, Accuracy = 0.9166666666666666
# It. 6
# Training: MSE = 0.0019296796538750354, Accuracy = 1.0
# Test: MSE = 0.003302361808617336, Accuracy = 1.0
# It. 7
# Training: MSE = 0.0024000062844501116, Accuracy = 1.0
# Test: MSE = 0.0041531135773923, Accuracy = 1.0
# It. 8
# Training: MSE = 0.002673605352768778, Accuracy = 1.0
# Test: MSE = 0.005250976875724106, Accuracy = 1.0
# Final result
#                 Mean mse    Std mse    Mean Accuracy    Std Accuracy
# ------------  ----------  ---------  ---------------  --------------
# Training Set  0.00949189  0.0197819         0.992832       0.0202755
# Test Set      0.0133685   0.0253073         0.990741       0.0261891
