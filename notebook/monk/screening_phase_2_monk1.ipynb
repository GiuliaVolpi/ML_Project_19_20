# %%
import sys
from os import path
sys.path.insert(0, "../../")
sys.path.insert(0, "./")

from isanet.model import Mlp
from isanet.optimizer import SGD
from isanet.datasets.monk import load_monk
from isanet.utils.model_utils import printMSE, printAcc, plotHistory
import numpy as np
from tabulate import tabulate

# %%
def print_table(data):
    table = [["Training Set",data[0],data[1]],
         ["Test Set",data[2],data[3]]]
    print(tabulate(table, headers=["MSE", "Accuracy"]))

def print_table_final(data):
    table = [["Training Set",data[0],data[1], data[2], data[3]],
         ["Test Set",data[4],data[5],data[6], data[7] ]]
    print(tabulate(table, headers=["Mean mse","Std mse", "Mean Accuracy", "Std Accuracy"]))

# %% [markdown]
# # Monk 1

# %%
#Load dataset
print("Load Monk DataSet")
X_train, Y_train = load_monk("1", "train")
X_test, Y_test = load_monk("1", "test")
# Out:
# Load Monk DataSet

# %%
len(X_train)
# Out:
# 124

# %% [markdown]
# ## Batch

# %% [markdown]
# ### test:
# - 17->3->1
# - lr: 0.2
# - kernel_regularizer: 0
# - momentum: 0.2
# - nesterov: True

# %% [markdown]
# <p>Learning rate e momentum bassi.</p>

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 0.003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.2,
        momentum = 0.2,
        nesterov = True
    ))

model.fit(X_train,
            Y_train, 
            epochs=600, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                    MSE    Accuracy
# ------------  --------  ----------
# Training Set  0.249997         0.5
# Test Set      0.249998         0.5

# %% [markdown]
# ### test:
# - 17->3->1
# - lr: 0.9
# - kernel_regularizer: 0
# - momentum: 0.2
# - nesterov: True

# %% [markdown]
# Alzo il learning rate

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 0.003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.9,
        momentum = 0.2,
        nesterov = True
    ))

model.fit(X_train,
            Y_train, 
            epochs=1000, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                    MSE    Accuracy
# ------------  --------  ----------
# Training Set  0.126962    0.846774
# Test Set      0.181585    0.738426

# %% [markdown]
# ### test:
# - 17->3->1
# - lr: 0.2
# - kernel_regularizer: 0
# - momentum: 0.9
# - nesterov: True

# %% [markdown]
# Alzo solo il momentum.

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 0.0003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.0003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.2,
        momentum = 0.9,
        nesterov = True
    ))

model.fit(X_train,
            Y_train, 
            epochs=1200, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                    MSE    Accuracy
# ------------  --------  ----------
# Training Set  0.114332    0.879032
# Test Set      0.178249    0.787037

# %% [markdown]
# ### test:
# - 17->3->1
# - lr: 0.8
# - kernel_regularizer: 0
# - momentum: 0.9
# - nesterov: True

# %% [markdown]
# Alzo sia momentum che learning rate.

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 0.003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.8,
        momentum = 0.9,
        nesterov = True
    ))

model.fit(X_train,
            Y_train, 
            epochs=1400, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                      MSE    Accuracy
# ------------  ----------  ----------
# Training Set  0.00272451           1
# Test Set      0.00384432           1

# %% [markdown]
# ### test:
# - 17->4->1
# - lr: 0.91
# - kernel_regularizer: 0
# - momentum: 0.9
# - nesterov: True

# %% [markdown]
# Provo aggiungendo un neurone.

# %%
model = Mlp()
model.add(4, input= 17, kernel_initializer = 0.003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.91,
        momentum = 0.9,
        nesterov = True
    ))

model.fit(X_train,
            Y_train, 
            epochs=1000, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                      MSE    Accuracy
# ------------  ----------  ----------
# Training Set  0.00265141           1
# Test Set      0.00446272           1

# %% [markdown]
# ### test:
# - 17->3->1
# - lr: 0.8
# - kernel_regularizer: 0
# - momentum: 0.9
# - nesterov: False

# %% [markdown]
# Senza Nesterov sempra che abbia bisogno di più epoche per convergere.

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 0.003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.8,
        momentum = 0.9,
        nesterov = False
    ))

model.fit(X_train,
            Y_train, 
            epochs=1200, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                      MSE    Accuracy
# ------------  ----------  ----------
# Training Set  0.00610887           1
# Test Set      0.00994069           1

# %% [markdown]
# Infatti ha bisogno, come possiamo vedere qua sotto, di circa 1200 epoche (contro le 600 di prima).

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 0.003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.8,
        momentum = 0.9,
        nesterov = False
    ))

model.fit(X_train,
            Y_train, 
            epochs=1200, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                      MSE    Accuracy
# ------------  ----------  ----------
# Training Set  0.00371446           1
# Test Set      0.00614145           1

# %% [markdown]
# ### test:
# - 17->3->1
# - lr: 1
# - kernel_regularizer: 0
# - momentum: 0.0001
# - nesterov: True

# %% [markdown]
# <p>Non credo che Monk 1 vada mai in overfitting.
# <p>Volendo possiamo provare a mettere i pesi molto alti</p>

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 0.003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 1,
        momentum = 0.0001,
        nesterov = True
    ))

model.fit(X_train,
            Y_train, 
            epochs=8000, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                      MSE    Accuracy
# ------------  ----------  ----------
# Training Set  0.00351833           1
# Test Set      0.00559046           1

# %% [markdown]
# ### test:
# - 17->3->1
# - lr: 0.02
# - kernel_regularizer: 0
# - momentum: 0.01
# - nesterov: True

# %% [markdown]
# Underfitting

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 0.003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.02,
        momentum = 0.01,
        nesterov = True
    ))

model.fit(X_train,
            Y_train, 
            epochs=5000, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                 MSE    Accuracy
# ------------  -----  ----------
# Training Set   0.25         0.5
# Test Set       0.25         0.5

# %% [markdown]
# ## Online

# %% [markdown]
# ### test:
# - 17->4->1
# - lr: 0.01
# - kernel_regularizer: 0
# - momentum: 0.01
# - nesterov: True

# %% [markdown]
# <p>Learning rate e momentum bassi.</p>
# <p>Ha però un andamento più a zig-zag (stochastic)</p>

# %%
model = Mlp()
model.add(4, input= 17, kernel_initializer = 0.0003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.0003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.01,
        momentum = 0.01,
        nesterov = True
    ))

model.fit(X_train,
            Y_train, 
            epochs=300, 
            batch_size=1,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                    MSE    Accuracy
# ------------  --------  ----------
# Training Set  0.249999         0.5
# Test Set      0.25             0.5

# %% [markdown]
# ### test:
# - 17->4->1
# - lr: 0.8
# - kernel_regularizer: 0
# - momentum: 0.9
# - nesterov: True

# %% [markdown]
# Aumento troppo (lr e momentum del miglior batch).

# %%
model = Mlp()
model.add(4, input= 17, kernel_initializer = 0.0003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.0003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.8,
        momentum = 0.9,
        nesterov = True
    ))

model.fit(X_train,
            Y_train, 
            epochs=300, 
            batch_size=1,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                    MSE    Accuracy
# ------------  --------  ----------
# Training Set  0.161303    0.83871
# Test Set      0.167165    0.833333

# %% [markdown]
# ### test:
# - 17->4->1
# - lr: 0.5
# - kernel_regularizer: 0
# - momentum: 0.2
# - nesterov: True

# %% [markdown]
# <p>Parametri migliorati leggermente</p>

# %%
model = Mlp()
model.add(4, input= 17, kernel_initializer = 0.0003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.0003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.5,
        momentum = 0.2,
        nesterov = True
    ))

model.fit(X_train,
            Y_train, 
            epochs=700, 
            batch_size=1,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                     MSE    Accuracy
# ------------  ---------  ----------
# Training Set  0.064662     0.935484
# Test Set      0.0835847    0.916667

# %% [markdown]
# ### test:
# - 17->4->1
# - lr: 0.5
# - kernel_regularizer: 0
# - momentum: 0.2
# - nesterov: True

# %% [markdown]
# Parametri migliori.

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 0.0003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.0003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.4,
        momentum = 0.8,
        nesterov = False
    ))

model.fit(X_train,
            Y_train, 
            epochs=1000, 
            batch_size=1,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                       MSE    Accuracy
# ------------  -----------  ----------
# Training Set  0.000166752           1
# Test Set      0.000230717           1

# %% [markdown]
# ### test:
# - 17->4->1
# - lr: 0.6
# - kernel_regularizer: 0
# - momentum: 0.7
# - nesterov: True

# %% [markdown]
# <p>Aumentando sia lr che momentum.</p>
# <p>Notiamo un andamento a scalini.</p>

# %%
model = Mlp()
model.add(4, input= 17, kernel_initializer = 0.0003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.0003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.6,
        momentum = 0.7,
        nesterov = True
    ))

model.fit(X_train,
            Y_train, 
            epochs=300, 
            batch_size=1,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                     MSE    Accuracy
# ------------  ---------  ----------
# Training Set  0.0645967    0.935484
# Test Set      0.0834726    0.916667

# %% [markdown]
# ### test:
# - 17->4->1
# - lr: 0.2
# - kernel_regularizer: 0
# - momentum: 0.3
# - nesterov: False

# %% [markdown]
# Togliendo Nesterov vediamo che ha bisogno di più epoche per convergere.

# %%
model = Mlp()
model.add(4, input= 17, kernel_initializer = 0.0003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.0003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.2,
        momentum = 0.3,
        nesterov = False
    ))

model.fit(X_train,
            Y_train, 
            epochs=300, 
            batch_size=1,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                     MSE    Accuracy
# ------------  ---------  ----------
# Training Set  0.0652112    0.935484
# Test Set      0.0844457    0.916667

# %%
model = Mlp()
model.add(4, input= 17, kernel_initializer = 0.0003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.0003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.2,
        momentum = 0.3,
        nesterov = False
    ))

model.fit(X_train,
            Y_train, 
            epochs=600, 
            batch_size=1,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                     MSE    Accuracy
# ------------  ---------  ----------
# Training Set  0.0304459    0.959677
# Test Set      0.0550482    0.916667

# %% [markdown]
# ## Mini Batch

# %% [markdown]
# ### test:
# - 17->4->1
# - lr: 0.2
# - kernel_regularizer: 0
# - momentum: 0.3
# - nesterov: True

# %% [markdown]
# <p>Parametri troppo bassi.</p>

# %%
model = Mlp()
model.add(4, input= 17, kernel_initializer = 0.0003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.0003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.2,
        momentum = 0.3,
        nesterov = True
    ))

model.fit(X_train,
            Y_train, 
            epochs=200, 
            batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                 MSE    Accuracy
# ------------  -----  ----------
# Training Set   0.25         0.5
# Test Set       0.25         0.5

# %% [markdown]
# ### test:
# - 17->4->1
# - lr: 0.5
# - kernel_regularizer: 0
# - momentum: 0.6
# - nesterov: True

# %% [markdown]
# <p>Alzo un po' i parametri</p>

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 0.0003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.0003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.6,
        momentum = 0.7,
        nesterov = False
    ))

model.fit(X_train,
            Y_train, 
            epochs=1500, 
            batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                      MSE    Accuracy
# ------------  ----------  ----------
# Training Set  0.00296555           1
# Test Set      0.00465701           1

# %% [markdown]
# ### test:
# - 17->4->1
# - lr: 0.8
# - kernel_regularizer: 0
# - momentum: 0.9
# - nesterov: True

# %% [markdown]
# Vediamo che converge prima del batch

# %%
model = Mlp()
model.add(4, input= 17, kernel_initializer = 0.0003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.0003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.8,
        momentum = 0.9,
        nesterov = True
    ))

model.fit(X_train,
            Y_train, 
            epochs=200, 
            batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                     MSE    Accuracy
# ------------  ---------  ----------
# Training Set  0.0665559    0.935484
# Test Set      0.08684      0.916667

# %% [markdown]
# ### test:
# - 17->4->1
# - lr: 0.8
# - kernel_regularizer: 0
# - momentum: 0.9
# - nesterov: False

# %% [markdown]
# Senza Nesterov converge più lentamente.

# %%
model = Mlp()
model.add(4, input= 17, kernel_initializer = 0.0003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.0003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.8,
        momentum = 0.9,
        nesterov = False
    ))

model.fit(X_train,
            Y_train, 
            epochs=300, 
            batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                      MSE    Accuracy
# ------------  ----------  ----------
# Training Set  0.0030394            1
# Test Set      0.00496994           1

# %% [markdown]
# # Final model (batch)

# %% [markdown]
# Vedi monk1_analysis

# %% [markdown]
# ### test:
# - 17->4->1
# - lr: 0.81
# - kernel_regularizer: 0
# - momentum: 0.9
# - nesterov: True

# %%
model = Mlp()
model.add(4, input= 17, kernel_initializer = 0.0003, kernel_regularizer = 0)
model.add(1, kernel_initializer = 0.0003, kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.81,
        momentum = 0.9,
        nesterov = True
    ))

model.fit(X_train,
            Y_train, 
            epochs=1200, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history, loss = 'MSE', orientation = "horizontal", name = "monk1")
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
#                      MSE    Accuracy
# ------------  ----------  ----------
# Training Set  0.00242074           1
# Test Set      0.00463241           1
