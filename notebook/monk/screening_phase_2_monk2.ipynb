# %%
import sys
from os import path
sys.path.insert(0, "../../ISANet/")
sys.path.insert(0, "./")

from isanet.model import Mlp
from isanet.optimizer import SGD
from isanet.datasets.monk import load_monk
from isanet.utils.model_utils import printMSE, printAcc, plotHistory
import numpy as np
from tabulate import tabulate

# %%
def print_table(data):
    table = [["Training Set",data[0],data[1]],
         ["Test Set",data[2],data[3]]]
    print(tabulate(table, headers=["MSE", "Accuracy"]))

def print_table_final(data):
    table = [["Training Set",data[0],data[1], data[2], data[3]],
         ["Test Set",data[4],data[5],data[6], data[7] ]]
    print(tabulate(table, headers=["Mean mse","Std mse", "Mean Accuracy", "Std Accuracy"]))

# %% [markdown]
# # Monk 2

# %%
#Load dataset
print("Load Monk DataSet")
X_train, Y_train = load_monk("2", "train")
X_test, Y_test = load_monk("2", "test")
# Out:
# Load Monk DataSet

# %%
len(X_train)
# Out:
# 169

# %% [markdown]
# ## Batch

# %% [markdown]
# ### test:
# - 17->3->1
# - lr: 0.1
# - kernel_regularizer: 0
# - momentum: 0.1
# - nesterov: True

# %% [markdown]
# <p>Learning rate e momentum bassi.</p>

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.1,
        momentum = 0.1,
        nesterov = True
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=3000, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                    MSE    Accuracy
# ------------  --------  ----------
# Training Set  0.231601    0.621302
# Test Set      0.22234     0.671296

# %% [markdown]
# ### test:
# - 17->3->1
# - lr: 0.2
# - kernel_regularizer: 0
# - momentum: 0.2
# - nesterov: True

# %% [markdown]
# Notiamo che la curva del test scavalca quella del training.

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.2,
        momentum = 0.2,
        nesterov = True
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=6000, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                    MSE    Accuracy
# ------------  --------  ----------
# Training Set  0.155671    0.810651
# Test Set      0.166224    0.759259

# %% [markdown]
# ### test:
# - 17->3->1
# - lr: 0.6
# - kernel_regularizer: 0
# - momentum: 0.2
# - nesterov: True

# %% [markdown]
# Aumento learning rate e momentum.

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.6,
        momentum = 0.2,
        nesterov = True
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=3500, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                     MSE    Accuracy
# ------------  ---------  ----------
# Training Set  0.0445819    1
# Test Set      0.0526472    0.997685

# %% [markdown]
# ### test:
# - 17->3->1
# - lr: 0.6
# - kernel_regularizer: 0
# - momentum: 0.6
# - nesterov: True

# %% [markdown]
# Aumentando il momentum vedo che converge prima.

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.6,
        momentum = 0.6,
        nesterov = True
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=1200, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                    MSE    Accuracy
# ------------  --------  ----------
# Training Set  0.154433    0.757396
# Test Set      0.172183    0.747685

# %% [markdown]
# ### test:
# - 17->10->1
# - lr: 0.5
# - kernel_regularizer: 0
# - momentum: 0.5
# - nesterov: True

# %% [markdown]
# Ho aumentato i neuroni.

# %%
model = Mlp()
model.add(10, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.5,
        momentum = 0.5,
        nesterov = True
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=2000, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                     MSE    Accuracy
# ------------  ---------  ----------
# Training Set  0.0975979    0.905325
# Test Set      0.114544     0.895833

# %% [markdown]
# ### test:
# - 17->3->1
# - lr: 0.7
# - kernel_regularizer: 0
# - momentum: 0.8
# - nesterov: True

# %% [markdown]
# Aumento ancora i parametri.

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.7,
        momentum = 0.8,
        nesterov = True
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=500, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                    MSE    Accuracy
# ------------  --------  ----------
# Training Set  0.164348    0.757396
# Test Set      0.174515    0.717593

# %% [markdown]
# ### test:
# - 17->3->1
# - lr: 0.8
# - kernel_regularizer: 0
# - momentum: 0.9
# - nesterov: True

# %% [markdown]
# Aumento ancora i parametri.

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.8,
        momentum = 0.9,
        nesterov = True
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=300, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                     MSE    Accuracy
# ------------  ---------  ----------
# Training Set  0.0364057           1
# Test Set      0.0436558           1

# %% [markdown]
# ## Online

# %% [markdown]
# ### test:
# - 17->3->1
# - lr: 0.8
# - kernel_regularizer: 0
# - momentum: 0.9
# - nesterov: True

# %% [markdown]
# Buoni parametri per il batch non vanno bene per l'online.

# %%
model = Mlp()
model.add(10, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.1,
        momentum = 0.4,
        nesterov = False
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=185, 
            batch_size=1,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                      MSE    Accuracy
# ------------  ----------  ----------
# Training Set  0.00196767           1
# Test Set      0.00228827           1

# %% [markdown]
# ### test:
# - 17->3->1
# - lr: 0.01
# - kernel_regularizer: 0
# - momentum: 0.9
# - nesterov: True

# %% [markdown]
# <p>Dobbiamo avere un learning rate più basso.</p>
# <p>Converge più velocemente del batch.</p>

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.01,
        momentum = 0.9,
        nesterov = True
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=185, 
            batch_size=1,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                      MSE    Accuracy
# ------------  ----------  ----------
# Training Set  0.00969046           1
# Test Set      0.0121764            1

# %% [markdown]
# ### test:
# - 17->3->1
# - lr: 0.01
# - kernel_regularizer: 0
# - momentum: 0.5
# - nesterov: True

# %% [markdown]
# Abbassando il momentum le cose non vanno tanto bene.

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.01,
        momentum = 0.5,
        nesterov = True
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=185, 
            batch_size=1,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                    MSE    Accuracy
# ------------  --------  ----------
# Training Set  0.227649    0.621302
# Test Set      0.2208      0.671296

# %% [markdown]
# ### test:
# - 17->3->1
# - lr: 0.01
# - kernel_regularizer: 0
# - momentum: 0.9
# - nesterov: False

# %% [markdown]
# Senza Nesterov converge più lentamente.

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.01,
        momentum = 0.9,
        nesterov = False
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=250, 
            batch_size=1,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                      MSE    Accuracy
# ------------  ----------  ----------
# Training Set  0.00308699           1
# Test Set      0.00355023           1

# %% [markdown]
# ## Mini Batch

# %% [markdown]
# ### test:
# - 17->3->1
# - lr: 0.01
# - kernel_regularizer: 0
# - momentum: 0.9
# - nesterov: True

# %% [markdown]
# <p>Provo i migliori parametri dell'online.</p>
# <p>No buono.</p>

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.01,
        momentum = 0.9,
        nesterov = True
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=600, 
            batch_size=68,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                    MSE    Accuracy
# ------------  --------  ----------
# Training Set  0.235238    0.621302
# Test Set      0.22303     0.671296

# %% [markdown]
# ### test:
# - 17->3->1
# - lr: 0.1
# - kernel_regularizer: 0
# - momentum: 0.9
# - nesterov: True

# %% [markdown]
# Aumento il learning rate.

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.1,
        momentum = 0.9,
        nesterov = True
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=600, 
            batch_size=68,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                    MSE    Accuracy
# ------------  --------  ----------
# Training Set  0.108381    0.899408
# Test Set      0.126032    0.868056

# %% [markdown]
# ### test:
# - 17->3->1
# - lr: 0.9
# - kernel_regularizer: 0
# - momentum: 0.01
# - nesterov: True

# %% [markdown]
# <p>Aumento il learning rate abbassando il momentum.</p>
# <p>Vediamo che ha bisogno do più epoche per convergere.</p>

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.9,
        momentum = 0.001,
        nesterov = False
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=1500, 
            batch_size=68,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                      MSE    Accuracy
# ------------  ----------  ----------
# Training Set  0.00300916           1
# Test Set      0.00349005           1

# %% [markdown]
# ### test:
# - 17->3->1
# - lr: 0.9
# - kernel_regularizer: 0
# - momentum: 0.8
# - nesterov: True

# %% [markdown]
# Ho alto sia il learnong rate sia il momentum.

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.9,
        momentum = 0.8,
        nesterov = True
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=200, 
            batch_size=68,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                     MSE    Accuracy
# ------------  ---------  ----------
# Training Set  0.0339868           1
# Test Set      0.0405714           1

# %% [markdown]
# ### test:
# - 17->3->1
# - lr: 0.9
# - kernel_regularizer: 0
# - momentum: 0.8
# - nesterov: False

# %% [markdown]
# Tolto Nesterov ediamo che ha bisogno di più epoche per convergere.

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.9,
        momentum = 0.8,
        nesterov = False
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=600, 
            batch_size=68,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
#                       MSE    Accuracy
# ------------  -----------  ----------
# Training Set  0.000893851           1
# Test Set      0.00102958            1

# %% [markdown]
# # Final model (batch)

# %% [markdown]
# Vedi monk2_analysis

# %% [markdown]
# # Prova con Nesterov corretto

# %%
model = Mlp()
model.add(3, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.8,
        momentum = 0.9,
        nesterov = True
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=1200, 
            #batch_size=68,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history, loss = 'MSE', orientation = "horizontal", name = "monk2")
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
#                       MSE    Accuracy
# ------------  -----------  ----------
# Training Set  0.000841015           1
# Test Set      0.000974469           1
