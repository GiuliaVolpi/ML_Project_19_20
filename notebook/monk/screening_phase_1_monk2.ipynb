# %%
import sys
from os import path
sys.path.insert(0, "../../ISANet/")
sys.path.insert(0, "./")

from isanet.model import Mlp
from isanet.optimizer import SGD
from isanet.datasets.monk import load_monk
from isanet.utils.model_utils import printMSE, printAcc, plotHistory
import numpy as np
from tabulate import tabulate

# %%
def print_table(data):
    table = [["Training Set",data[0],data[1]],
         ["Test Set",data[2],data[3]]]
    print(tabulate(table, headers=["MSE", "Accuracy"]))

def print_table_final(data):
    table = [["Training Set",data[0],data[1], data[2], data[3]],
         ["Test Set",data[4],data[5],data[6], data[7] ]]
    print(tabulate(table, headers=["Mean mse","Std mse", "Mean Accuracy", "Std Accuracy"]))

# %% [markdown]
# # - monk 2

# %%
print("Load Monk DataSet")
X_train, Y_train = load_monk("2", "train")
X_test, Y_test = load_monk("2", "test")
# Out:
# Load Monk DataSet

# %% [markdown]
# ## test:
# - 17->3->1
# - lr: 0.2
# - kernel_regularizer: 0
# - momentum: 0.2
# - nesterov: True

# %%
print("Load Monk DataSet")
X_train, Y_train = load_monk("2", "train")
X_test, Y_test = load_monk("2", "test")

print("Build the model")
model = Mlp()
model.add(3, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.1,
        momentum = 0.1,
        nesterov = True
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=3000, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
# Load Monk DataSet
# Build the model
#                    MSE    Accuracy
# ------------  --------  ----------
# Training Set  0.228893    0.621302
# Test Set      0.220146    0.671296

# %%
print("Load Monk DataSet")
X_train, Y_train = load_monk("2", "train")
X_test, Y_test = load_monk("2", "test")

print("Build the model")
model = Mlp()
model.add(3, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.6,
        momentum = 0.1,
        nesterov = True
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=3000, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
# Load Monk DataSet
# Build the model
#                    MSE    Accuracy
# ------------  --------  ----------
# Training Set  0.201747    0.573964
# Test Set      0.204654    0.560185

# %%
print("Load Monk DataSet")
X_train, Y_train = load_monk("2", "train")
X_test, Y_test = load_monk("2", "test")

print("Build the model")
model = Mlp()
model.add(3, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.6,
        momentum = 0.6,
        nesterov = True
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=1200, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
# Load Monk DataSet
# Build the model
#                     MSE    Accuracy
# ------------  ---------  ----------
# Training Set  0.01147             1
# Test Set      0.0130346           1

# %% [markdown]
# # final test

# %%
print("Load Monk DataSet")
X_train, Y_train = load_monk("2", "train")
X_test, Y_test = load_monk("2", "test")

print("Build the model")
model = Mlp()
model.add(3, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.7,
        momentum = 0.8,
        nesterov = True
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=500, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
# Load Monk DataSet
# Build the model
#                     MSE    Accuracy
# ------------  ---------  ----------
# Training Set  0.0117784           1
# Test Set      0.0139496           1

# %%
print("Load Monk DataSet")
X_train, Y_train = load_monk("2", "train")
X_test, Y_test = load_monk("2", "test")

print("Build the model")
model = Mlp()
model.add(3, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.8,
        momentum = 0.9,
        nesterov = True
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=300, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
# Load Monk DataSet
# Build the model
#                      MSE    Accuracy
# ------------  ----------  ----------
# Training Set  0.00326335           1
# Test Set      0.00382799           1

# %%
print("Load Monk DataSet")
X_train, Y_train = load_monk("2", "train")
X_test, Y_test = load_monk("2", "test")

print("Build the model")
model = Mlp()
model.add(3, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.9006,
        momentum = 0.9,
        nesterov = True
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=185, 
            #batch_size=31,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
# Load Monk DataSet
# Build the model
#                     MSE    Accuracy
# ------------  ---------  ----------
# Training Set  0.0894217    0.893491
# Test Set      0.107112     0.863426

# %% [markdown]
# # test online

# %%
print("Load Monk DataSet")
X_train, Y_train = load_monk("2", "train")
X_test, Y_test = load_monk("2", "test")

print("Build the model")
model = Mlp()
model.add(3, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.01,
        momentum = 0.9,
        nesterov = True
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=185, 
            batch_size=1,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
# Load Monk DataSet
# Build the model
#                      MSE    Accuracy
# ------------  ----------  ----------
# Training Set  0.00169522           1
# Test Set      0.00197106           1

# %%
print("Load Monk DataSet")
X_train, Y_train = load_monk("2", "train")
X_test, Y_test = load_monk("2", "test")

print("Build the model")
model = Mlp()
model.add(3, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.09,
        momentum = 0,
        nesterov = False
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=250, 
            batch_size=1,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
# Load Monk DataSet
# Build the model
#                      MSE    Accuracy
# ------------  ----------  ----------
# Training Set  0.00534848           1
# Test Set      0.00607921           1

# %% [markdown]
# # minibatch

# %%
print("Load Monk DataSet")
X_train, Y_train = load_monk("2", "train")
X_test, Y_test = load_monk("2", "test")

print("Build the model")
model = Mlp()
model.add(3, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.1,
        momentum = 0.9,
        nesterov = True
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=600, 
            batch_size=68,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
# Load Monk DataSet
# Build the model
#                     MSE    Accuracy
# ------------  ---------  ----------
# Training Set  0.0169306           1
# Test Set      0.0213944           1

# %%
print("Load Monk DataSet")
X_train, Y_train = load_monk("2", "train")
X_test, Y_test = load_monk("2", "test")

print("Build the model")
model = Mlp()
model.add(3, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

model.set_optimizer(
    SGD(
        lr = 0.9,
        momentum = 0,
        nesterov = False
    ))
# Batch
model.fit(X_train,
            Y_train, 
            epochs=1000, 
            batch_size=68,
            validation_data = [X_test, Y_test],
            verbose=0) 

plotHistory(model.history )
data = [   model.history["loss_mse"][-1],
           model.history["acc"][-1],
           model.history["val_loss_mse"][-1],
           model.history["val_acc"][-1]  
       ]
print_table(data)
# Out:
# Load Monk DataSet
# Build the model
#                     MSE    Accuracy
# ------------  ---------  ----------
# Training Set  0.014398            1
# Test Set      0.0171835           1

# %% [markdown]
# # Final

# %%
mse_means_train = []
accs_means_train = []

mse_means_val = []
accs_means_val = []
for i in range(0,9):
    print("Build the model")
    model = Mlp()
    model.add(4, input= 17, kernel_initializer = 1/np.sqrt(17), kernel_regularizer = 0)
    model.add(1, kernel_initializer = 1/np.sqrt(4), kernel_regularizer = 0)

    model.set_optimizer(
        SGD(
            lr = 0.903,
            momentum = 0.9,
            nesterov = True
        ))
    # Batch
    model.fit(X_train,
                Y_train, 
                epochs=1200, 
                #batch_size=31,
                validation_data = [X_test, Y_test],
                verbose=0) 
    mse_means_train.append(model.history["loss_mse"][-1])
    accs_means_train.append(model.history["acc"][-1])
    mse_means_val.append(model.history["val_loss_mse"][-1])
    accs_means_val.append(model.history["val_acc"][-1])
    
    print("Training: MSE = {}, Accuracy = {}".format(model.history["loss_mse"][-1],model.history["acc"][-1]))
    print("Test: MSE = {}, Accuracy = {}".format(model.history["val_loss_mse"][-1],model.history["val_acc"][-1]))
    
    plotHistory(model.history )

print("Final result")
plotHistory(model.history )
data = [    np.mean(mse_means_train),
            np.std(mse_means_train),
            np.mean(accs_means_train),
            np.std(accs_means_train),
            np.mean(mse_means_val),
            np.std(mse_means_val),
            np.mean(accs_means_val),
            np.std(accs_means_val)
       ]
print_table_final(data)
# Out:
# Build the model
# Training: MSE = 0.0005584847374241258, Accuracy = 1.0
# Test: MSE = 0.0006426681278413219, Accuracy = 1.0
# Build the model
# Training: MSE = 0.0007227293021134946, Accuracy = 1.0
# Test: MSE = 0.0008217114442178622, Accuracy = 1.0
# Build the model
# Training: MSE = 0.0006313193045890886, Accuracy = 1.0
# Test: MSE = 0.0007225823309694845, Accuracy = 1.0
# Build the model
# Training: MSE = 0.0007924240471039105, Accuracy = 1.0
# Test: MSE = 0.0009987203843810936, Accuracy = 1.0
# Build the model
# Training: MSE = 0.0005741367520302128, Accuracy = 1.0
# Test: MSE = 0.000653453915426921, Accuracy = 1.0
# Build the model
# Training: MSE = 0.0007382441358682549, Accuracy = 1.0
# Test: MSE = 0.0009229737968817021, Accuracy = 1.0
# Build the model
# Training: MSE = 0.0007061518260918743, Accuracy = 1.0
# Test: MSE = 0.0008016346201599834, Accuracy = 1.0
# Build the model
# Training: MSE = 0.0006130322298243114, Accuracy = 1.0
# Test: MSE = 0.0007521641458200701, Accuracy = 1.0
# Build the model
# Training: MSE = 0.000681180458715209, Accuracy = 1.0
# Test: MSE = 0.000785365498821275, Accuracy = 1.0
# Final result
#                  Mean mse      Std mse    Mean Accuracy    Std Accuracy
# ------------  -----------  -----------  ---------------  --------------
# Training Set  0.000668634  7.469e-05                  1               0
# Test Set      0.00078903   0.000109913                1               0
